# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
print(tf.__version__)
# Out:
# 2.3.1

# %%
imdb = keras.datasets.imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 2s 0us/step

# %%
print("Training entries: {}, labels: {}".format(len(train_data), len(train_labels)))
# Out:
# Training entries: 25000, labels: 25000

# %%
len(train_data[0]), len(train_data[1])
# Out:
# (218, 189)

# %%
# 単語を整数にマッピングする辞書
word_index = imdb.get_word_index()

# インデックスの最初の方は予約済み
word_index = {k:(v+3) for k,v in word_index.items()} 
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 1s 0us/step

# %%
decode_review(train_data[0])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data,
                                                        value=word_index["<PAD>"],
                                                        padding='post',
                                                        maxlen=256)

test_data = keras.preprocessing.sequence.pad_sequences(test_data,
                                                       value=word_index["<PAD>"],
                                                       padding='post',
                                                       maxlen=256)

# %%
# 入力の形式は映画レビューで使われている語彙数（10,000語）
vocab_size = 10000

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)
# Out:
# Epoch 1/40
# 30/30 [==============================] - 1s 27ms/step - loss: 0.6924 - accuracy: 0.5037 - val_loss: 0.6910 - val_accuracy: 0.4975
# Epoch 2/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6878 - accuracy: 0.6183 - val_loss: 0.6843 - val_accuracy: 0.6774
# Epoch 3/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6767 - accuracy: 0.7107 - val_loss: 0.6697 - val_accuracy: 0.7255
# Epoch 4/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6551 - accuracy: 0.7497 - val_loss: 0.6443 - val_accuracy: 0.7562
# Epoch 5/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6218 - accuracy: 0.7804 - val_loss: 0.6087 - val_accuracy: 0.7832
# Epoch 6/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5789 - accuracy: 0.8081 - val_loss: 0.5666 - val_accuracy: 0.7993
# Epoch 7/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5310 - accuracy: 0.8240 - val_loss: 0.5225 - val_accuracy: 0.8173
# Epoch 8/40
# 30/30 [==============================] - 1s 18ms/step - loss: 0.4825 - accuracy: 0.8455 - val_loss: 0.4803 - val_accuracy: 0.8304
# Epoch 9/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4377 - accuracy: 0.8585 - val_loss: 0.4425 - val_accuracy: 0.8419
# Epoch 10/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3983 - accuracy: 0.8714 - val_loss: 0.4112 - val_accuracy: 0.8509
# Epoch 11/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3647 - accuracy: 0.8817 - val_loss: 0.3857 - val_accuracy: 0.8574
# Epoch 12/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3368 - accuracy: 0.8901 - val_loss: 0.3654 - val_accuracy: 0.8655
# Epoch 13/40
# 30/30 [==============================] - 1s 23ms/step - loss: 0.3127 - accuracy: 0.8958 - val_loss: 0.3492 - val_accuracy: 0.8692
# Epoch 14/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2925 - accuracy: 0.9017 - val_loss: 0.3364 - val_accuracy: 0.8707
# Epoch 15/40
# 30/30 [==============================] - 1s 29ms/step - loss: 0.2751 - accuracy: 0.9067 - val_loss: 0.3254 - val_accuracy: 0.8761
# Epoch 16/40
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2595 - accuracy: 0.9113 - val_loss: 0.3168 - val_accuracy: 0.8769
# Epoch 17/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2459 - accuracy: 0.9165 - val_loss: 0.3102 - val_accuracy: 0.8776
# Epoch 18/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2337 - accuracy: 0.9203 - val_loss: 0.3040 - val_accuracy: 0.8801
# Epoch 19/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2217 - accuracy: 0.9244 - val_loss: 0.3000 - val_accuracy: 0.8796
# Epoch 20/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2115 - accuracy: 0.9273 - val_loss: 0.2954 - val_accuracy: 0.8830
# Epoch 21/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2017 - accuracy: 0.9311 - val_loss: 0.2924 - val_accuracy: 0.8828
# Epoch 22/40
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1925 - accuracy: 0.9357 - val_loss: 0.2915 - val_accuracy: 0.8819
# Epoch 23/40
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1847 - accuracy: 0.9389 - val_loss: 0.2881 - val_accuracy: 0.8843
# Epoch 24/40
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1762 - accuracy: 0.9436 - val_loss: 0.2878 - val_accuracy: 0.8848
# Epoch 25/40
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1692 - accuracy: 0.9447 - val_loss: 0.2861 - val_accuracy: 0.8847
# Epoch 26/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1619 - accuracy: 0.9488 - val_loss: 0.2855 - val_accuracy: 0.8850
# Epoch 27/40
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1553 - accuracy: 0.9519 - val_loss: 0.2855 - val_accuracy: 0.8854
# Epoch 28/40
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1490 - accuracy: 0.9540 - val_loss: 0.2860 - val_accuracy: 0.8855
# Epoch 29/40
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1432 - accuracy: 0.9573 - val_loss: 0.2865 - val_accuracy: 0.8859
# Epoch 30/40
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1373 - accuracy: 0.9593 - val_loss: 0.2880 - val_accuracy: 0.8866
# Epoch 31/40
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1325 - accuracy: 0.9607 - val_loss: 0.2896 - val_accuracy: 0.8860
# Epoch 32/40
# 30/30 [==============================] - 1s 24ms/step - loss: 0.1272 - accuracy: 0.9629 - val_loss: 0.2910 - val_accuracy: 0.8858
# Epoch 33/40
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1219 - accuracy: 0.9650 - val_loss: 0.2923 - val_accuracy: 0.8855
# Epoch 34/40
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1173 - accuracy: 0.9673 - val_loss: 0.2948 - val_accuracy: 0.8852
# Epoch 35/40
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1127 - accuracy: 0.9692 - val_loss: 0.2976 - val_accuracy: 0.8854
# Epoch 36/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1087 - accuracy: 0.9698 - val_loss: 0.3005 - val_accuracy: 0.8849
# Epoch 37/40
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1044 - accuracy: 0.9712 - val_loss: 0.3023 - val_accuracy: 0.8836
# Epoch 38/40
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1002 - accuracy: 0.9731 - val_loss: 0.3053 - val_accuracy: 0.8830
# Epoch 39/40
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0971 - accuracy: 0.9745 - val_loss: 0.3078 - val_accuracy: 0.8835
# Epoch 40/40
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0928 - accuracy: 0.9759 - val_loss: 0.3118 - val_accuracy: 0.8815

# %%
results = model.evaluate(test_data,  test_labels, verbose=2)

print(results)
# Out:
# 782/782 - 1s - loss: 0.3316 - accuracy: 0.8716
# [0.33157506585121155, 0.8715599775314331]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # 図のクリア

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
